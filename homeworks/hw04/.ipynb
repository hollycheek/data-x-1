# %% [markdown]
# # Homework 4 - Pandas

# %% [markdown]
# ## NAME: Holly Cheek

# %% [markdown]
# ## STUDENT ID: 3033094443

# %%
# Load required modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Pandas Introduction
#
# ## Reading File

# %% [markdown]
# #### 1.1) Read the CSV file called 'data3.csv' into a dataframe called df.
# #### Data description
# * Data source: http://www.fao.org/nr/water/aquastat/data/query/index.html
# * Data, units:
# * GDP, current USD (CPI adjusted)
# * NRI, mm/yr
# * Population density, inhab/km^2
# * Total area of the country, 1000 ha = 10km^2
# * Total Population, unit 1000 inhabitants

# %%
# your code here
df = pd.read_csv('data3.csv')

# %% [markdown]
# #### 1.2) Display the first 10 rows of the dataframe.

# %%
# your code here
df.head(10)
# Out:
#         Area  Area Id              Variable Name  Variable Id    Year  \
# 0  Argentina      9.0  Total area of the country       4100.0  1962.0
# 1  Argentina      9.0  Total area of the country       4100.0  1967.0
# 2  Argentina      9.0  Total area of the country       4100.0  1972.0
# 3  Argentina      9.0  Total area of the country       4100.0  1977.0
# 4  Argentina      9.0  Total area of the country       4100.0  1982.0
# 5  Argentina      9.0  Total area of the country       4100.0  1987.0
# 6  Argentina      9.0  Total area of the country       4100.0  1992.0
# 7  Argentina      9.0  Total area of the country       4100.0  1997.0
# 8  Argentina      9.0  Total area of the country       4100.0  2002.0
# 9  Argentina      9.0  Total area of the country       4100.0  2007.0
#
#       Value Symbol  Other
# 0  278040.0      E    NaN
# 1  278040.0      E    NaN
# 2  278040.0      E    NaN
# 3  278040.0      E    NaN
# 4  278040.0      E    NaN
# 5  278040.0      E    NaN
# 6  278040.0      E    NaN
# 7  278040.0      E    NaN
# 8  278040.0      E    NaN
# 9  278040.0      E    NaN

# %% [markdown]
# #### 1.3) Display the column names.

# %%
# your code here
list(df)
# Out:
# ['Area',
#  'Area Id',
#  'Variable Name',
#  'Variable Id',
#  'Year',
#  'Value',
#  'Symbol',
#  'Other']

# %% [markdown]
# #### 1.4) Use iloc to display the first 3 rows and first 4 columns.

# %%
# your code here
df.iloc[0:3, 0:4]
# Out:
#         Area  Area Id              Variable Name  Variable Id
# 0  Argentina      9.0  Total area of the country       4100.0
# 1  Argentina      9.0  Total area of the country       4100.0
# 2  Argentina      9.0  Total area of the country       4100.0

# %% [markdown]
# ## Data Preprocessing
#
# #### 2.1) Find all the rows that  have 'NaN' in the 'Symbol' column. Display first 5 rows.
#
# ##### Hint : You might have to use a mask

# %%
# your code here
df.where(df['Symbol'] == 'NaaN').head(5)
# Out:
#   Area  Area Id Variable Name  Variable Id  Year  Value Symbol  Other
# 0  NaN      NaN           NaN          NaN   NaN    NaN    NaN    NaN
# 1  NaN      NaN           NaN          NaN   NaN    NaN    NaN    NaN
# 2  NaN      NaN           NaN          NaN   NaN    NaN    NaN    NaN
# 3  NaN      NaN           NaN          NaN   NaN    NaN    NaN    NaN
# 4  NaN      NaN           NaN          NaN   NaN    NaN    NaN    NaN

# %% [markdown]
# #### 2.2)  Now, we will try to get rid of the NaN valued rows and columns. First, drop the column 'Other' which only has 'NaN' values. Then drop all other rows that have any column with a value 'NaN'. Store the result in place. Then display the last 5 rows of the dataframe.

# %%
# your code here
clean_df = df[['Area', 'Area Id', "Variable Name", "Variable Id", "Year", "Value", "Symbol"]].dropna()
clean_df.head(20)
# Out:
#          Area  Area Id              Variable Name  Variable Id    Year  \
# 0   Argentina      9.0  Total area of the country       4100.0  1962.0
# 1   Argentina      9.0  Total area of the country       4100.0  1967.0
# 2   Argentina      9.0  Total area of the country       4100.0  1972.0
# 3   Argentina      9.0  Total area of the country       4100.0  1977.0
# 4   Argentina      9.0  Total area of the country       4100.0  1982.0
# 5   Argentina      9.0  Total area of the country       4100.0  1987.0
# 6   Argentina      9.0  Total area of the country       4100.0  1992.0
# 7   Argentina      9.0  Total area of the country       4100.0  1997.0
# 8   Argentina      9.0  Total area of the country       4100.0  2002.0
# 9   Argentina      9.0  Total area of the country       4100.0  2007.0
# 10  Argentina      9.0  Total area of the country       4100.0  2012.0
# 11  Argentina      9.0  Total area of the country       4100.0  2014.0
# 12  Argentina      9.0           Total population       4104.0  1962.0
# 13  Argentina      9.0           Total population       4104.0  1967.0
# 14  Argentina      9.0           Total population       4104.0  1972.0
# 15  Argentina      9.0           Total population       4104.0  1977.0
# 16  Argentina      9.0           Total population       4104.0  1982.0
# 17  Argentina      9.0           Total population       4104.0  1987.0
# 18  Argentina      9.0           Total population       4104.0  1992.0
# 19  Argentina      9.0           Total population       4104.0  1997.0
#
#        Value Symbol
# 0   278040.0      E
# 1   278040.0      E
# 2   278040.0      E
# 3   278040.0      E
# 4   278040.0      E
# 5   278040.0      E
# 6   278040.0      E
# 7   278040.0      E
# 8   278040.0      E
# 9   278040.0      E
# 10  278040.0      E
# 11  278040.0      E
# 12   21288.0      E
# 13   22932.0      E
# 14   24783.0      E
# 15   26879.0      E
# 16   28994.0      E
# 17   31326.0      E
# 18   33655.0      E
# 19   35834.0      E

# %% [markdown]
# #### 2.3) For our analysis we do not want all the columns in our dataframe. Lets  drop all the redundant columns/ features.
# #### **Drop columns**: **Area Id, Variable Id, Symbol**. Save the new dataframe as df1. Display the first 5 rows of the new dataframe.

# %%
# your code here
df1 = clean_df[['Area', 'Variable Name','Year','Value']]
df1.head(5)
# Out:
#         Area              Variable Name    Year     Value
# 0  Argentina  Total area of the country  1962.0  278040.0
# 1  Argentina  Total area of the country  1967.0  278040.0
# 2  Argentina  Total area of the country  1972.0  278040.0
# 3  Argentina  Total area of the country  1977.0  278040.0
# 4  Argentina  Total area of the country  1982.0  278040.0

# %% [markdown]
# #### 2.4) Display all the unique values in your new dataframe for each of the columns: Area, Variable Name, Year.

# %%
# your code here
print(df1['Area'].unique(), df1['Variable Name'].unique(), df1['Year'].unique(), df1['Value'].unique())
# Out:
# ['Argentina' 'Australia' 'Germany' 'Iceland' 'Ireland' 'Sweden'
#  'United States of America'] ['Total area of the country' 'Total population' 'Population density'
#  'Gross Domestic Product (GDP)' 'National Rainfall Index (NRI)'] [1962. 1967. 1972. 1977. 1982. 1987. 1992. 1997. 2002. 2007. 2012. 2014.
#  2015. 1963. 1970. 1974. 1978. 1984. 1990. 1964. 1981. 1985. 1996. 2001.
#  1969. 1973. 1979. 1993. 1971. 1975. 1986. 1991. 1998. 2000. 1965. 1983.
#  1988. 1995.] [2.78040000e+05 2.12880000e+04 2.29320000e+04 2.47830000e+04
#  2.68790000e+04 2.89940000e+04 3.13260000e+04 3.36550000e+04
#  3.58340000e+04 3.78890000e+04 3.99700000e+04 4.20950000e+04
#  4.34170000e+04 7.65600000e+00 8.24800000e+00 8.91300000e+00
#  9.66700000e+00 1.04300000e+01 1.12700000e+01 1.21000000e+01
#  1.28900000e+01 1.36300000e+01 1.43800000e+01 1.51400000e+01
#  1.56200000e+01 2.44506049e+10 2.42566676e+10 3.47330005e+10
#  5.67810001e+10 8.43074868e+10 1.11000000e+11 2.29000000e+11
#  2.93000000e+11 9.77245135e+10 3.29000000e+11 6.04000000e+11
#  5.48000000e+11 7.81600000e+02 8.03200000e+02 8.48900000e+02
#  8.91000000e+02 9.68600000e+02 9.58800000e+02 8.87300000e+02
#  1.06200000e+03 7.74122000e+05 1.06910000e+04 1.19760000e+04
#  1.33640000e+04 1.42120000e+04 1.51010000e+04 1.63150000e+04
#  1.75380000e+04 1.85130000e+04 1.95140000e+04 2.09760000e+04
#  2.29110000e+04 2.39690000e+04 1.38100000e+00 1.54700000e+00
#  1.72600000e+00 1.83600000e+00 1.95100000e+00 2.10800000e+00
#  2.26600000e+00 2.39100000e+00 2.52100000e+00 2.71000000e+00
#  2.96000000e+00 3.09600000e+00 1.98835256e+10 3.03785418e+10
#  5.19287383e+10 1.10000000e+11 1.94000000e+11 1.89000000e+11
#  3.25000000e+11 4.36000000e+11 3.94000000e+11 8.53000000e+11
#  1.54000000e+12 1.34000000e+12 5.96400000e+02 6.72100000e+02
#  7.68500000e+02 6.93400000e+02 6.37000000e+02 6.94700000e+02
#  6.35500000e+02 7.17100000e+02 3.56970000e+04 3.57030000e+04
#  3.57040000e+04 3.57100000e+04 3.57170000e+04 3.57380000e+04
#  7.42380000e+04 7.71070000e+04 7.87000000e+04 7.85250000e+04
#  7.78120000e+04 7.78640000e+04 8.00760000e+04 8.19940000e+04
#  8.17000000e+04 8.08550000e+04 8.04780000e+04 8.06890000e+04
#  2.08000000e+02 2.16000000e+02 2.20500000e+02 2.20000000e+02
#  2.18000000e+02 2.18100000e+02 2.24300000e+02 2.29700000e+02
#  2.28800000e+02 2.26400000e+02 2.25300000e+02 2.25800000e+02
#  2.99000000e+11 5.98000000e+11 7.74000000e+11 1.29000000e+12
#  2.12000000e+12 2.22000000e+12 2.08000000e+12 3.44000000e+12
#  3.54000000e+12 3.36000000e+12 7.85800000e+02 6.78200000e+02
#  6.71900000e+02 7.75100000e+02 7.55600000e+02 7.39400000e+02
#  7.90900000e+02 8.35500000e+02 1.03000000e+04 1.82600000e+02
#  1.97400000e+02 2.09900000e+02 2.22100000e+02 2.33100000e+02
#  2.46900000e+02 2.59900000e+02 2.72800000e+02 2.86900000e+02
#  3.05400000e+02 3.23400000e+02 3.29400000e+02 1.77300000e+00
#  1.91700000e+00 2.03800000e+00 2.15600000e+00 2.26300000e+00
#  2.39700000e+00 2.52300000e+00 2.64900000e+00 2.78500000e+00
#  2.96500000e+00 3.14000000e+00 3.19800000e+00 2.84916516e+08
#  6.21225962e+08 8.46506911e+08 2.22653869e+09 3.23280422e+09
#  5.56538403e+09 7.13878800e+09 7.59612605e+09 9.16179822e+09
#  2.12938412e+10 1.41945190e+10 1.65984948e+10 8.16000000e+02
#  9.63200000e+02 1.01000000e+03 9.32600000e+02 9.68500000e+02
#  1.09500000e+03 9.93200000e+02 9.23400000e+02 7.02800000e+03
#  2.82200000e+03 2.88200000e+03 3.02800000e+03 3.28800000e+03
#  3.50100000e+03 3.56600000e+03 3.58200000e+03 3.70600000e+03
#  3.96800000e+03 4.38900000e+03 4.66800000e+03 4.68800000e+03
#  4.01500000e+01 4.10100000e+01 4.30800000e+01 4.67800000e+01
#  4.98200000e+01 5.07400000e+01 5.09700000e+01 5.27300000e+01
#  5.64600000e+01 6.24500000e+01 6.64200000e+01 6.67000000e+01
#  2.26034968e+09 3.34363677e+09 6.32515932e+09 1.12609772e+10
#  2.14988799e+10 3.39586277e+10 5.59813610e+10 8.28167796e+10
#  1.28000000e+11 2.70000000e+11 2.25000000e+11 2.38000000e+11
#  1.09800000e+03 1.03000000e+03 9.91600000e+02 1.15400000e+03
#  1.07100000e+03 1.12800000e+03 1.12200000e+03 1.20200000e+03
#  4.50300000e+04 4.47420000e+04 7.57600000e+03 7.87100000e+03
#  8.12200000e+03 8.24600000e+03 8.32300000e+03 8.41400000e+03
#  8.67800000e+03 8.85900000e+03 8.91200000e+03 9.15300000e+03
#  9.54300000e+03 9.77900000e+03 1.68200000e+01 1.74800000e+01
#  1.80400000e+01 1.83100000e+01 1.84800000e+01 1.86900000e+01
#  1.92700000e+01 1.96700000e+01 1.97900000e+01 2.03300000e+01
#  2.13300000e+01 2.18600000e+01 1.75114773e+10 2.74634092e+10
#  4.82639150e+10 9.31367751e+10 1.13000000e+11 1.80000000e+11
#  2.80000000e+11 2.64000000e+11 4.88000000e+11 5.44000000e+11
#  4.93000000e+11 6.14100000e+02 5.81700000e+02 6.14800000e+02
#  6.15900000e+02 6.78600000e+02 6.76500000e+02 6.46600000e+02
#  7.00400000e+02 9.62909000e+05 9.63203000e+05 9.83151000e+05
#  1.91861000e+05 2.03713000e+05 2.13220000e+05 2.23091000e+05
#  2.33954000e+05 2.45425000e+05 2.57908000e+05 2.72883000e+05
#  2.88471000e+05 3.01656000e+05 3.14799000e+05 3.21774000e+05
#  1.99300000e+01 2.11600000e+01 2.21400000e+01 2.31700000e+01
#  2.43000000e+01 2.54900000e+01 2.67800000e+01 2.83400000e+01
#  2.99500000e+01 3.13200000e+01 3.20200000e+01 3.27300000e+01
#  6.05000000e+11 8.62000000e+11 1.28000000e+12 2.09000000e+12
#  3.34000000e+12 4.87000000e+12 6.54000000e+12 8.61000000e+12
#  1.10000000e+13 1.45000000e+13 1.62000000e+13 1.79000000e+13
#  9.28500000e+02 9.52200000e+02 1.00800000e+03 9.49200000e+02
#  9.74600000e+02 1.02000000e+03 1.00500000e+03 9.38700000e+02]

# %% [markdown]
# #### 2.5) Convert the 'Year' column float values to pandas datetime objects, where each year is represented as the first day of that year. Also display the first 5 values of the Year column after conversion.
#
# ##### For eg: 1962.0 will be represented as 1962-01-01

# %%
# your code here
year_col = pd.to_datetime(df1['Year'])
year_col.head(5)
# Out:
# 0   1970-01-01 00:00:00.000001962
# 1   1970-01-01 00:00:00.000001967
# 2   1970-01-01 00:00:00.000001972
# 3   1970-01-01 00:00:00.000001977
# 4   1970-01-01 00:00:00.000001982
# Name: Year, dtype: datetime64[ns]

# %% [markdown]
# ## Plot

# %% [markdown]
# #### 3.1) Plot a bar graph showing the count for each unique value in the column 'Area'. Give it a title.

# %%
# your code here
df1['Area'].value_counts().plot(kind = 'bar')

# %% [markdown]
# ## Extract specific statistics from the preprocessed data:
#
# #### 4.1)  Create a dataframe 'dftemp' to store rows where Area is 'Iceland'. Display the dataframe.

# %%
# your code here
dftemp = df1[df1['Area'] == 'Iceland']
dftemp
# Out:
#         Area                  Variable Name    Year         Value
# 166  Iceland      Total area of the country  1962.0  1.030000e+04
# 167  Iceland      Total area of the country  1967.0  1.030000e+04
# 168  Iceland      Total area of the country  1972.0  1.030000e+04
# 169  Iceland      Total area of the country  1977.0  1.030000e+04
# 170  Iceland      Total area of the country  1982.0  1.030000e+04
# 171  Iceland      Total area of the country  1987.0  1.030000e+04
# 172  Iceland      Total area of the country  1992.0  1.030000e+04
# 173  Iceland      Total area of the country  1997.0  1.030000e+04
# 174  Iceland      Total area of the country  2002.0  1.030000e+04
# 175  Iceland      Total area of the country  2007.0  1.030000e+04
# 176  Iceland      Total area of the country  2012.0  1.030000e+04
# 177  Iceland      Total area of the country  2014.0  1.030000e+04
# 178  Iceland               Total population  1962.0  1.826000e+02
# 179  Iceland               Total population  1967.0  1.974000e+02
# 180  Iceland               Total population  1972.0  2.099000e+02
# 181  Iceland               Total population  1977.0  2.221000e+02
# 182  Iceland               Total population  1982.0  2.331000e+02
# 183  Iceland               Total population  1987.0  2.469000e+02
# 184  Iceland               Total population  1992.0  2.599000e+02
# 185  Iceland               Total population  1997.0  2.728000e+02
# 186  Iceland               Total population  2002.0  2.869000e+02
# 187  Iceland               Total population  2007.0  3.054000e+02
# 188  Iceland               Total population  2012.0  3.234000e+02
# 189  Iceland               Total population  2015.0  3.294000e+02
# 190  Iceland             Population density  1962.0  1.773000e+00
# 191  Iceland             Population density  1967.0  1.917000e+00
# 192  Iceland             Population density  1972.0  2.038000e+00
# 193  Iceland             Population density  1977.0  2.156000e+00
# 194  Iceland             Population density  1982.0  2.263000e+00
# 195  Iceland             Population density  1987.0  2.397000e+00
# 196  Iceland             Population density  1992.0  2.523000e+00
# 197  Iceland             Population density  1997.0  2.649000e+00
# 198  Iceland             Population density  2002.0  2.785000e+00
# 199  Iceland             Population density  2007.0  2.965000e+00
# 200  Iceland             Population density  2012.0  3.140000e+00
# 201  Iceland             Population density  2015.0  3.198000e+00
# 202  Iceland   Gross Domestic Product (GDP)  1962.0  2.849165e+08
# 203  Iceland   Gross Domestic Product (GDP)  1967.0  6.212260e+08
# 204  Iceland   Gross Domestic Product (GDP)  1972.0  8.465069e+08
# 205  Iceland   Gross Domestic Product (GDP)  1977.0  2.226539e+09
# 206  Iceland   Gross Domestic Product (GDP)  1982.0  3.232804e+09
# 207  Iceland   Gross Domestic Product (GDP)  1987.0  5.565384e+09
# 208  Iceland   Gross Domestic Product (GDP)  1992.0  7.138788e+09
# 209  Iceland   Gross Domestic Product (GDP)  1997.0  7.596126e+09
# 210  Iceland   Gross Domestic Product (GDP)  2002.0  9.161798e+09
# 211  Iceland   Gross Domestic Product (GDP)  2007.0  2.129384e+10
# 212  Iceland   Gross Domestic Product (GDP)  2012.0  1.419452e+10
# 213  Iceland   Gross Domestic Product (GDP)  2015.0  1.659849e+10
# 214  Iceland  National Rainfall Index (NRI)  1967.0  8.160000e+02
# 215  Iceland  National Rainfall Index (NRI)  1971.0  9.632000e+02
# 216  Iceland  National Rainfall Index (NRI)  1975.0  1.010000e+03
# 217  Iceland  National Rainfall Index (NRI)  1981.0  9.326000e+02
# 218  Iceland  National Rainfall Index (NRI)  1986.0  9.685000e+02
# 219  Iceland  National Rainfall Index (NRI)  1991.0  1.095000e+03
# 220  Iceland  National Rainfall Index (NRI)  1997.0  9.932000e+02
# 221  Iceland  National Rainfall Index (NRI)  1998.0  9.234000e+02

# %% [markdown]
# #### 4.2) Print the years (with the same format as 2.5) when the National Rainfall Index (NRI) was greater than 900 and less than 950 in Iceland. Use the dataframe you created in the previous question 'dftemp'.

# %%
# your code here
dftemp[(dftemp['Variable Name'] == 'National Rainfall Index (NRI)') & 
       (dftemp['Value'] > 900) &
       (dftemp['Value'] < 950)]
# Out:
#         Area                  Variable Name    Year  Value
# 217  Iceland  National Rainfall Index (NRI)  1981.0  932.6
# 221  Iceland  National Rainfall Index (NRI)  1998.0  923.4

# %% [markdown]
# ## US statistics:

# %% [markdown]
# #### 5.1) Create a new DataFrame called **`df_usa`** that only contains values where 'Area' is equal to 'United States of America'. Set the indices to be the 'Year' column   (Use .set_index( ), set inplace=True ). Display the dataframe head.

# %%
# your code here
df_usa = df1[df1['Area'] == 'United States of America'].set_index('Year')
df_usa.head()
# Out:
#                             Area              Variable Name     Value
# Year
# 1962.0  United States of America  Total area of the country  962909.0
# 1967.0  United States of America  Total area of the country  962909.0
# 1972.0  United States of America  Total area of the country  962909.0
# 1977.0  United States of America  Total area of the country  962909.0
# 1982.0  United States of America  Total area of the country  962909.0

# %% [markdown]
# #### 5.2) Pivot the DataFrame so that the unique values in the column 'Variable Name' becomes the columns. The DataFrame values should be the ones in the the 'Value' column. Save it in df_usa. Display the dataframe head.

# %%
# your code here
df_vars = df_usa.pivot(index = df_usa.index, columns = 'Variable Name')['Value']
df_usa = df_usa.drop(columns = ["Variable Name","Value"])
df_usa[df_vars.columns] = df_vars
df_usa.head()
# Out:
#                             Area  Gross Domestic Product (GDP)  \
# Year
# 1962.0  United States of America                  6.050000e+11
# 1967.0  United States of America                  8.620000e+11
# 1972.0  United States of America                  1.280000e+12
# 1977.0  United States of America                  2.090000e+12
# 1982.0  United States of America                  3.340000e+12
#
#         National Rainfall Index (NRI)  Population density  \
# Year
# 1962.0                            NaN               19.93
# 1967.0                            NaN               21.16
# 1972.0                            NaN               22.14
# 1977.0                            NaN               23.17
# 1982.0                            NaN               24.30
#
#         Total area of the country  Total population
# Year
# 1962.0                   962909.0          191861.0
# 1967.0                   962909.0          203713.0
# 1972.0                   962909.0          213220.0
# 1977.0                   962909.0          223091.0
# 1982.0                   962909.0          233954.0

# %% [markdown]
# #### 5.3) Rename new columns to  ['GDP','NRI','PD','Area','Population'] and display the head.

# %%
# your code here
df_usa = df_usa.drop(columns = 'Area')
df_usa = df_usa.rename({"Gross Domestic Product (GDP)": "GDP",
                       "National Rainfall Index (NRI)": "NRI",
                       "Population density": "PD",
                       "Total area of the country": "Area",
                       "Total population": "Population"} ,axis = "columns")
df_usa.head()
# Out:
#                  GDP  NRI     PD      Area  Population
# Year
# 1962.0  6.050000e+11  NaN  19.93  962909.0    191861.0
# 1967.0  8.620000e+11  NaN  21.16  962909.0    203713.0
# 1972.0  1.280000e+12  NaN  22.14  962909.0    213220.0
# 1977.0  2.090000e+12  NaN  23.17  962909.0    223091.0
# 1982.0  3.340000e+12  NaN  24.30  962909.0    233954.0

# %% [markdown]
# #### 5.4) Replace all 'Nan' values in df_usa with 0. Display the head of the dataframe.

# %%
# your code here
df_usa = df_usa.fillna(value=0)
df_usa.head()
# Out:
#                  GDP  NRI     PD      Area  Population
# Year
# 1962.0  6.050000e+11  0.0  19.93  962909.0    191861.0
# 1967.0  8.620000e+11  0.0  21.16  962909.0    203713.0
# 1972.0  1.280000e+12  0.0  22.14  962909.0    213220.0
# 1977.0  2.090000e+12  0.0  23.17  962909.0    223091.0
# 1982.0  3.340000e+12  0.0  24.30  962909.0    233954.0

# %% [markdown]
# ## Use df_usa:
#
# #### 6.1) Multiply the 'Area' column for all rows by 10 (so instead of 1000 ha, the unit becomes 100 ha = 1km^2). Display the dataframe head.

# %%
# your code here
df_usa['Area'] *= 10
df_usa.head()
# Out:
#                  GDP  NRI     PD       Area  Population
# Year
# 1962.0  6.050000e+11  0.0  19.93  9629090.0    191861.0
# 1967.0  8.620000e+11  0.0  21.16  9629090.0    203713.0
# 1972.0  1.280000e+12  0.0  22.14  9629090.0    213220.0
# 1977.0  2.090000e+12  0.0  23.17  9629090.0    223091.0
# 1982.0  3.340000e+12  0.0  24.30  9629090.0    233954.0

# %% [markdown]
# #### 6.2) Create a new column in df_usa called 'GDP/capita' and populate it with the calculated GDP per capita. Round the results to two decimal points. Display the dataframe head.
# GDP per capita = (GDP / Population) * 1000

# %%
# your code here
df_usa['GDP/capita'] = (df_usa["GDP"] / df_usa["Population"]).round(2)
df_usa.head()
# Out:
#                  GDP  NRI     PD       Area  Population   GDP/capita
# Year
# 1962.0  6.050000e+11  0.0  19.93  9629090.0    191861.0   3153324.54
# 1967.0  8.620000e+11  0.0  21.16  9629090.0    203713.0   4231443.26
# 1972.0  1.280000e+12  0.0  22.14  9629090.0    213220.0   6003189.19
# 1977.0  2.090000e+12  0.0  23.17  9629090.0    223091.0   9368374.34
# 1982.0  3.340000e+12  0.0  24.30  9629090.0    233954.0  14276310.73

# %% [markdown]
# #### 6.3) Find the maximum value of the 'NRI' column in the US (using pandas methods). What year does the max value occur? Display the values.

# %%
# your code here
max_NRI = df_usa.max(axis = 0)['NRI']
max_index = df_usa.idxmax(axis = 0)['NRI']
print(max_NRI, max_index)
# Out:
# 1020.0 1992.0

# %% [markdown]
# ## Congratulations on completing hw4! Don't forget to click Kernel -> Restart & Run All, save your file, download or print as pdf, and submit pdf to Gradescope.
